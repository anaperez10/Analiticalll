# %%
#Importar librerias.
import pandas as pd

# %% [markdown]
# **CARGAR LAS BASES DE DATOS DESDE EL GITHUB**

# %%
#Cargar base de datos 
#Base de datos de encuesta de satisfaccion empleados.
url="https://raw.githubusercontent.com/anaperez10/Analiticalll/main/Bases%20de%20datos/employee_survey_data.csv"
encuestaem= pd.read_csv(url)
encuestaem.head(8)
# Out:
#    EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# 0           1                      3.0              4.0              2.0
# 1           2                      3.0              2.0              4.0
# 2           3                      2.0              2.0              1.0
# 3           4                      4.0              4.0              3.0
# 4           5                      4.0              1.0              3.0
# 5           6                      3.0              2.0              2.0
# 6           7                      1.0              3.0              1.0
# 7           8                      1.0              2.0              3.0

# %%
url1="https://raw.githubusercontent.com/anaperez10/Analiticalll/main/Bases%20de%20datos/general_data.csv"
datosg=pd.read_csv(url1 ,sep=";")
datosg.head(5)
# Out:
#    Age     BusinessTravel              Department  DistanceFromHome  \
# 0   51      Travel_Rarely                   Sales                 6
# 1   31  Travel_Frequently  Research & Development                10
# 2   32  Travel_Frequently  Research & Development                17
# 3   38         Non-Travel  Research & Development                 2
# 4   32      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  JobLevel  ...  \
# 0          2  Life Sciences              1           1  Female         1  ...
# 1          1  Life Sciences              1           2  Female         1  ...
# 2          4          Other              1           3    Male         4  ...
# 3          5  Life Sciences              1           4    Male         3  ...
# 4          1        Medical              1           5    Male         1  ...
#
#   NumCompaniesWorked Over18  PercentSalaryHike  StandardHours  \
# ...

# %%
url2="https://raw.githubusercontent.com/anaperez10/Analiticalll/main/Bases%20de%20datos/manager_survey_data.csv"
encuestama=pd.read_csv(url2)
encuestama.head(5)
# Out:
#    EmployeeID  JobInvolvement  PerformanceRating
# 0           1               3                  3
# 1           2               2                  4
# 2           3               3                  3
# 3           4               2                  3
# 4           5               3                  3

# %%
url3="https://raw.githubusercontent.com/anaperez10/Analiticalll/main/Bases%20de%20datos/retirement_info.csv"
retiros=pd.read_csv(url3,sep=";")
retiros.head(5)
# Out:
#    EmployeeID Attrition retirementDate retirementType resignationReason
# 0           2       Yes     15/10/2016    Resignation            Others
# 1           7       Yes     20/07/2016    Resignation            Stress
# 2          14       Yes     08/11/2016    Resignation            Others
# 3          29       Yes     15/10/2016    Resignation            Others
# 4          31       Yes     08/02/2016    Resignation            Salary

# %%
url4="https://raw.githubusercontent.com/anaperez10/Analiticalll/main/Bases%20de%20datos/in_time.csv"
entiempo=pd.read_csv(url4,sep=",")
entiempo.head(5)
#la basee de datos de las fechas no las entiendo.
# Out:
#    Unnamed: 0  2015-01-01           2015-01-02           2015-01-05  \
# 0           1         NaN  2015-01-02 09:43:45  2015-01-05 10:08:48
# 1           2         NaN  2015-01-02 10:15:44  2015-01-05 10:21:05
# 2           3         NaN  2015-01-02 10:17:41  2015-01-05 09:50:50
# 3           4         NaN  2015-01-02 10:05:06  2015-01-05 09:56:32
# 4           5         NaN  2015-01-02 10:28:17  2015-01-05 09:49:58
#
#             2015-01-06           2015-01-07           2015-01-08  \
# 0  2015-01-06 09:54:26  2015-01-07 09:34:31  2015-01-08 09:51:09
# 1                  NaN  2015-01-07 09:45:17  2015-01-08 10:09:04
# 2  2015-01-06 10:14:13  2015-01-07 09:47:27  2015-01-08 10:03:40
# 3  2015-01-06 10:11:07  2015-01-07 09:37:30  2015-01-08 10:02:08
# 4  2015-01-06 09:45:28  2015-01-07 09:49:37  2015-01-08 10:19:44
#
#             2015-01-09           2015-01-12           2015-01-13  ...  \
# 0  2015-01-09 10:09:25  2015-01-12 09:42:53  2015-01-13 10:13:06  ...
# ...
